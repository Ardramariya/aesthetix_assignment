# %%
import cv2
img=cv2.imread('/content/drive/MyDrive/EDA/istockphoto-636761588-612x612.jpg')

# %%
from PIL import Image
img=Image.open('/content/drive/MyDrive/EDA/istockphoto-636761588-612x612.jpg')
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
import skimage.io
img=skimage.io.imread(fname='/content/drive/MyDrive/EDA/istockphoto-636761588-612x612.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img.shape
# Out:
# (344, 612, 3)

# %%
img.size
# Out:
# 631584

# %%
c_img= img[50:200,100:300]
plt.imshow(c_img)

# %%
s_img=cv2.resize(img,(100,100))
plt.imshow(s_img)

# %%
cv2_imshow(s_img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
r_img=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(r_img)
# Out:
# <PIL.Image.Image image mode=RGB size=344x612>

# %%
n_img=255-img
cv2_imshow(n_img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cv2_imshow(rgb_img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=612x344>

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2_imshow(hsv_img)
# Out:
# <PIL.Image.Image image mode=RGB size=612x344>
