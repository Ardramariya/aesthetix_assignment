# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Employee.csv")

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
print(df['Education'])
# Out:
# 0       Bachelors
# 1       Bachelors
# 2       Bachelors
# 3         Masters
# 4         Masters
#           ...
# 4648    Bachelors
# 4649      Masters
# 4650      Masters
# 4651    Bachelors
# 4652    Bachelors
# Name: Education, Length: 4653, dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df_Bachelors=df[df['Education']=='Bachelors']

# %%
df_Bachelors
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 6     Bachelors         2015  New Delhi            3   38    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df_Bachelors_sorted=df_Bachelors.sort_values(by = 'EverBenched',ascending=False)
df_Bachelors_sorted.head()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
# 1109  Bachelors         2016  Bangalore            3   26    Male         Yes
# 3717  Bachelors         2015  Bangalore            3   35    Male         Yes
# 1117  Bachelors         2012  Bangalore            3   27    Male         Yes
# 1136  Bachelors         2018  Bangalore            3   27  Female         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4652                          4           0
# 1109                          4           0
# 3717                          2           0
# 1117                          5           0
# 1136                          5           1

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='scatter',x='Age',y='ExperienceInCurrentDomain')
plt.show()

# %%
count=df['JoiningYear'].value_counts()
count.plot(kind='bar')
plt.xlabel('JoiningYear')
plt.ylabel('JoiningYear')
plt.show()
